# %% [markdown]
# # A Quick Example Jupyter Notebook
#
# Jupyter notebooks are a way to combine text, math, and Python (or Julia) code into a single document. They're a great way to provide an interactive document for sharing ideas with interactive code!

# %% [markdown]
# Each "cell" of a Jupyter notebook can be individually selected to be for code, Markdown, or just raw. When you (double) click a cell, you can edit its content. To run a code cell or render a Markdown cell, just do Shift+Enter.

# %% [markdown]
# As you might expect, Markdown cells can use typical Markdown formatting, like **bold**, *italics*, and `teletype`. Hyperlinks also work as in Markdown, if you want to show someone some [fake news](http://www.cnn.com). Other typical Markdown notation includes:
#
# - nested lists
# - of several items
#   - with extra layers
#   - of indentation
# - if you want to do that
#
# 1. numbered lists
# 2. can also be made
# 3. which is nice

# %% [markdown]
# As you might *not* expect, Jupyter notebooks also support LaTeX-style math formatting. You can put math expressions inline like this: $y = 5x + 3$.
#
# You can also express (systems of) equations in various environments, but I find that `align*` works best.
#
# \begin{align*}
# v(m_t) &= \max_{c_t} U(c_t) + \beta E \left[ v(m_{t+1}) \right] ~~ \text{s.t.} \\
# a_t &= m_t - c_t, \\
# a_t &\geq 0, \\
# k_{t+1} &= a_t, \\
# b_{t+1} &= \mathsf{R} k_{t+1} + y_{t+1}, \\
# y_{t+1} &\sim F_{t+1}, \\
# U(c) &= \frac{c^{1-\rho}}{1-\rho}.
# \end{align*}

# %% [markdown]
# Code cells in Markdown can be used to express "chunks" of Python code that can be run one by one, or all in a row.

# %%
# Everything you can do in Python, you can do in a code cell!
# Like import things from other files
from ProcessSurveys import make_fig

# %%
# You can generate plots in a Jupyter notebook!
make_fig('The Simpsons')
